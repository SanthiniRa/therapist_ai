# %% [markdown]
# <a href="https://colab.research.google.com/github/SanthiniRa/therapist_ai/blob/main/start_cmd.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # setup

# %% [markdown]
# Steps used to set up in colab

# %%
# !git clone https://github.com/SanthiniRa/therapist_ai.git
# !ls /content
# %cd /content/therapist_ai/
add content in .env file

# !pip install -r requirement
# !pip install slowapi
# !pip install python-dotenv
# %cd /content/therapist_ai
# !nohup uvicorn backend.main:app --host 0.0.0.0 --port 8000 > backend.log 2>&1 &
import time
time.sleep(10)
from google.colab.output import eval_js
print(eval_js("google.colab.kernel.proxyPort(8000)"))

# %% [markdown]
# cmd to run the backend code

# %%
# !node -v
# !npm -v
# %cd /content/therapist_ai/frontend/therapist-chat

# !npm install

# !nohup npm start > node.log 2>&1 &
import time
time.sleep(10)
from google.colab.output import eval_js
print(eval_js("google.colab.kernel.proxyPort(3000)"))
# Out:
# /content/therapist_ai
# https://8000-m-s-kkb-usw1b2-bnxlefi7pzdh-b.us-west1-2.prod.colab.dev

# %%
# !pkill -f uvicorn
# !pkill -f react-scripts
# !fuser -k 8000/tcp
# !fuser -k 3000/tcp

# %cd /content/therapist_ai

# !nohup uvicorn backend.main:app --host 0.0.0.0 --port 8000 > backend.log 2>&1 &
import time
time.sleep(5)
# Out:
# /content/therapist_ai

# %%
# %cd /content/therapist_ai
# !tail -n 20 backend.log
# Out:
# /content/therapist_ai
# /usr/local/lib/python3.12/dist-packages/starlette/config.py:62: UserWarning: Config file '.env' not found.
#   warnings.warn(f"Config file '{env_file}' not found.")
# INFO:     Started server process [36678]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://0.0.0.0:8000 (Press CTRL+C to quit)

# %%
# %cd /content/therapist_ai/frontend/therapist-chat

# !HOST=0.0.0.0 PORT=3000 nohup npm start > node.log 2>&1 &
time.sleep(10)
# Out:
# /content/therapist_ai/frontend/therapist-chat

# %%
# %cd /content/therapist_ai/frontend/therapist-chat
# !tail -n 50 node.log
# Out:
# /content/therapist_ai/frontend/therapist-chat
#
# > therapist-chat@0.1.0 start
# > react-scripts start
#
# Attempting to bind to HOST environment variable: 0.0.0.0
# If this was unintentional, check that you haven't mistakenly set it in your shell.
# Learn more here: https://cra.link/advanced-config
#
# (node:36786) [DEP_WEBPACK_DEV_SERVER_ON_AFTER_SETUP_MIDDLEWARE] DeprecationWarning: 'onAfterSetupMiddleware' option is deprecated. Please use the 'setupMiddlewares' option.
# (Use `node --trace-deprecation ...` to show where the warning was created)
# (node:36786) [DEP_WEBPACK_DEV_SERVER_ON_BEFORE_SETUP_MIDDLEWARE] DeprecationWarning: 'onBeforeSetupMiddleware' option is deprecated. Please use the 'setupMiddlewares' option.
# Starting the development server...
#
# Compiled successfully!
#
# You can now view therapist-chat in the browser.
#
#   Local:            http://localhost:3000
#   On Your Network:  http://172.28.0.12:3000
#
# Note that the development build is not optimized.
# ...

# %%
from google.colab.output import eval_js
print(eval_js("google.colab.kernel.proxyPort(3000)"))
# Out:
# https://3000-m-s-kkb-usw1b2-bnxlefi7pzdh-b.us-west1-2.prod.colab.dev
